# %%
from rdkit.Chem import Draw
from rdkit import Chem

# %%
from matchms import Spectrum, Fragments
import numpy as np

# %%
import os
os.chdir('../programming_scripts/.')
print(os.getcwd())
# Out:
# C:\Users\dietr004\Documents\PhD\computational mass spectrometry\Spec2Struc\Project_SubstructureIdentification\scripts\programming_scripts

# %%
from Spec2Vec_annotation import load_model_and_data
from Spec2Vec_annotation import calc_similarity
from Spec2Vec_annotation import retrieve_top_hits
s2v_model, embeddings_smiles_DB = load_model_and_data()
smiles = embeddings_smiles_DB.smiles.to_numpy()
embeddings_DB = embeddings_smiles_DB.embeddings.to_list()
spectra_DB = embeddings_smiles_DB.spectra.to_list()

# %%
file = r"MotifDB\Urine derived Mass2Motifs\urine_mass2motif_133.m2m"
file = r"MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_3.m2m"

# %% [markdown]
# ### Parse mass 2 motif (m2m) files

# %%
def parse_m2m(file):
    """parses mass to motif by extraction the fragments, losses, names and (short) annotation

    ARGS:
        file (str): path to m2m file

    RETURNS:
        fragments_mz (list): mz values of fragments
        fragments_importance (list): LDA importance of fragments
        losses_mz (list): mz values of losses
        losses_importance (list): LDA importance of losses
        name (str): unique identifier of m2m
        annotation (str): short manually annotation
    """
    
    with open(file, "r") as motif_file:
        motif_file = motif_file.readlines()
    
    fragments_mz = []
    fragments_importance = []
    
    losses_mz = []
    losses_importance = []
    
    name = None
    annotation = None
    
    for line in motif_file:
        line = line.replace("\n", "")
        if line.startswith("fragment_"):
            frag_mz, frag_importance = line.split("_")[1].split(",")
            fragments_mz.append(float(frag_mz))
            fragments_importance.append(float(frag_importance))
        elif line.startswith("loss_"):
            loss_mz, loss_importance = line.split("_")[1].split(",")
            losses_mz.append(float(loss_mz))
            losses_importance.append(float(loss_importance))
        elif line.startswith("#NAME"):
            name = line.split(" ")[1]
        elif line.startswith("#SHORT_ANNOTATION"):
            annotation = line.split(" ", 1)[1]

    return fragments_mz, fragments_importance, losses_mz, losses_importance, name, annotation

# %% [markdown]
# ### Sort fragments in ascending order and also their importance/intensity

# %%
def sort_dependent_lists(loss_or_frag, intensities):
    """sorts two lists based on the values of one of the lists

    ARGS:
        loss_or_frag (list): list of mz values of either fragments or losses
        intensities (list): list of LDA importance values for either fragments or losses

    RETURNS:
        sorted_loss_or_frag (as np.array): sorted mz values for fragments or losses
        sorted_intensities (as np.array): based on sorted mz values sorted LDA importance values
    """

    combined_lists = list(zip(loss_or_frag, intensities))
    sorted_combined_lists = sorted(combined_lists, key=lambda x: x[0])
    sorted_loss_or_frag, sorted_intensities = zip(*sorted_combined_lists)

    return np.array(sorted_loss_or_frag), np.array(sorted_intensities)

# %% [markdown]
# ### Build a Motif spectrum

# %%
def build_spectrum(fragments_mz, fragments_importance, losses_mz, losses_importance, name, annotation):
    """builds a matchms spectrum object for the m2m

    ARGS:
        fragments_mz (list): mz values of fragments
        fragments_importance (list): LDA importance of fragments
        losses_mz (list): mz values of losses
        losses_importance (list): LDA importance of losses
        name (str): unique identifier of m2m
        annotation (str): short manually annotation

    RETURNS:
        motif_spectrum (matchms.spectrum.object): built spectrum based on given m2m frag, loss, name (as metadata) and annotation (as metadata)
    """
    
    sorted_fragments_mz, sorted_fragments_importance = sort_dependent_lists(fragments_mz, fragments_importance)
    sorted_losses_mz, sorted_losses_importance = sort_dependent_lists(fragments_mz, fragments_importance)
    
    motif_spectrum = Spectrum(
        mz=sorted_fragments_mz,
        intensities=sorted_fragments_importance,
        metadata={
            "id": name,
            "precursor_mz": max(fragments_mz),
            "annotation": annotation
        }
    )
    motif_spectrum.losses = Fragments(
    mz = sorted_losses_mz,
    intensities = sorted_losses_importance
    )

    return motif_spectrum

# %% [markdown]
# ### Spec2Vec calculation

# %%
def spec2vec_predictions(motif_spectrum):
    """predicts similar molecules based on the motif spectrum

    ARGS:
        motif_spectrum (matchms.spectrum.object): spectrum based on given m2m frag, loss, name (as metadata) and annotation (as metadata)

    RETURNS:
        top_smiles (list): list of SMILES (strings)
        top_scores (list): list of sv2 socres for each SMILES 
        annotation (str): short description of manual annotation
    """

    s2v_scores = calc_similarity(s2v_model, [motif_spectrum], embeddings_DB)
    top_scores, top_smiles, top_spectra = retrieve_top_hits(s2v_scores, 0, smiles, spectra_DB)

    annotation = motif_spectrum.get("annotation")

    return top_smiles, top_scores, annotation

# %% [markdown]
# ### Generate Spec2Vec Hit images and store them

# %%
def generate_png(top_smiles, top_scores, annotation, m2m_path):
    """generates Spec2Vec images for top 10 hits with manual annotation as title and stores them.

    ARGS:
        top_smiles (list): list of SMILES (strings)
        top_scores (list): list of sv2 socres for each SMILES 
        annotation (str): short description of manual annotation

    RETURNS:
        None
    """
    
    img = Draw.MolsToGridImage([Chem.MolFromSmiles(smi) for smi in top_smiles], molsPerRow=4, subImgSize=(300, 300), legends=[str(round(score,3)) for score in top_scores], returnPNG=False)

    font = ImageFont.truetype(r"C:\WINDOWS\FONTS\ARIAL.TTF", 24)
    font_color = (0,0,0) 

    draw = ImageDraw.Draw(img)
    
    
    text_x = img.width // 2  
    text_y = 10  

    draw.text((text_x, text_y), annotation, fill=font_color, font=font)
    img.save(m2m_path)

# %% [markdown]
# ---

# %% [markdown]
# ### Run against the entire Motif_DB

# %%
m2m_paths = []

MotifDB_folder = os.listdir('MotifDB')
for library_name in MotifDB_folder:
    mass2motif_folder = os.listdir(rf".\MotifDB\{library_name}")
    for mass2motif_name in mass2motif_folder:
        m2m_path = rf".\MotifDB\{library_name}\{mass2motif_name}"
        m2m_paths.append(m2m_path)

# %%
len(m2m_paths)
# Out:
# 996

# %%
for m2m_path in m2m_paths:
    print(m2m_path)
    fragments_mz, fragments_importance, losses_mz, losses_importance, name, annotation = parse_m2m(m2m_path)
    if fragments_mz:
        motif_spectrum = build_spectrum(fragments_mz, fragments_importance, losses_mz, losses_importance, name, annotation)
        top_smiles, top_scores, annotation = spec2vec_predictions(motif_spectrum)

        new_m2m_path = m2m_path.replace("MotifDB", "MotifDB_annotations_s2v", 1)[:-4]+"_SimMols.png"

        generate_png(top_smiles, top_scores, annotation, new_m2m_path)
# Out:
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_0.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_119.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_126.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_132.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_135.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_14.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_149.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_158.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_162.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_173.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_179.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_18.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_180.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_182.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_192.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_199.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_2.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_207.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_214.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_249.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_254.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_255.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_260.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_265.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_277.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_295.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_296.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_297.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_299.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_3.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_308.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif_322.m2m
# .\MotifDB\Euphorbia Plant Mass2Motifs\euphorbia_motif
m2m
# .\MotifDB\Photorhabdus and Xenorhabdus Mass2Motifs\rhabdus_motif_91.m2m
# .\MotifDB\Photorhabdus and Xenorhabdus Mass2Motifs\rhabdus_motif_95.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_102.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_104.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_111.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_134.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_147.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_154.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_174.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_191.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_192.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_203.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_217.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_256.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_259.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_285.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_301.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_363.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_364.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_385.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_392.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_408.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_412.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_434.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_449.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_47.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_474.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_506.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_529.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_530.m2m
# .\MotifDB\Planomonospora-associated Mass2Motifs\PLM_motif_93.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_108.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_109.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_117.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_120.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_121.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_130.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_140.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_141.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_148.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_149.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_153.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_163.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_164.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_165.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_167.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_168.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_169.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_172.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_179.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_191.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_28.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_3.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_33.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_34.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_40.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_48.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_51.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_60.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_64.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_86.m2m
# .\MotifDB\Rhamnaceae Plant Mass2Motifs\rhamn_motif_87.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_10.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_105.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_106.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_108.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_110.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_113.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_119.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_125.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_128.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_144.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_161.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_168.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_196.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_199.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_20.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_205.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_208.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_213.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_218.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_221.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_223.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_224.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_233.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_238.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_241.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_250.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_259.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_270.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_283.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_289.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_3.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_37.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_48.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_49.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_6.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_74.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_8.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_85.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_91.m2m
# .\MotifDB\Streptomyces and Salinispora Mass2Motifs\StrepSalini_motif_99.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_1.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_123.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_15.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_151.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_167.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_186.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_196.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_26.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_34.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_40.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_70.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_72.m2m
# .\MotifDB\Streptomyces S29\Streptomyc_motif_85.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_1.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_100.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_102.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_104.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_105.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_106.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_111.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_115.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_117.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_120.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_122.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_126.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_128.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_130.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_133.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_134.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_137.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_138.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_141.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_147.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_148.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_149.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_151.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_152.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_153.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_159.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_163.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_164.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_165.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_167.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_169.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_173.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_175.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_176.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_177.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_18.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_180.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_181.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_183.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_186.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_187.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_190.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_191.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_192.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_194.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_197.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_200.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_202.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_203.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_207.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_208.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_210.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_211.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_212.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_213.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_22.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_220.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_221.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_224.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_228.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_229.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_23.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_230.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_232.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_233.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_236.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_237.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_238.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_239.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_240.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_241.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_242.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_245.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_246.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_247.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_248.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_249.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_256.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_259.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_260.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_261.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_262.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_266.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_268.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_269.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_27.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_271.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_272.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_273.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_278.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_279.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_281.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_282.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_283.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_284.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_286.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_288.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_29.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_291.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_292.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_30.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_31.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_32.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_34.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_37.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_38.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_39.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_4.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_41.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_43.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_47.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_50.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_52.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_56.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_57.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_59.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_64.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_65.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_66.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_67.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_68.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_7.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_72.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_78.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_80.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_83.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_86.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_88.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_90.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_93.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_94.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_95.m2m
# .\MotifDB\Urine derived Mass2Motifs\urine_mass2motif_97.m2m

# %% [markdown]
# ---

# %% [markdown]
# ### Fun to play around with or for presentations

# %%
from molecule_slide_generator import * 
from rdkit.Chem import AllChem
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
all_props = []
mols = []
for smi, score, spec in zip(top_smiles, top_scores, top_spectra):
    mol = Chem.MolFromSmiles(smi)
    AllChem.Compute2DCoords(mol)
    if score > .80:
        color = '#3A662F'
    elif score < 0.80 and score > 0.60:
        color = '#e8860e'
    else:
        color = '#b52009'

    props = [TextProperty("S2V score", "S2V score: "+str(round(score,3)), color=color)]
    mols.append(mol)
    all_props.append(props)

# %%
sg = SlideGenerator(mols_per_row=2, rows=5, font_size=18, font='comicbd', number_of_properties=2, slide_width=800, slide_height=600)

# %%
png = sg.generate_slide(mols, all_props, 'example_slide.png')
